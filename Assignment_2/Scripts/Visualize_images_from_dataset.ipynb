# %% [markdown]
# <h1> Visualize the data </h1>

# %% [markdown]
# Show image from the dataset

# %%
import matplotlib.pyplot as plt
from keras.preprocessing import image

# Load an image using Keras
img_path = 'E:\\Dataset\\images\\1000410_ss_3bde284abbdafa186b0be8b8fcaa1e3c6d76ea40.1920x1080.jpg'
img = image.load_img(img_path, target_size=(1080,1920))  # You can adjust the target size as needed
img_array = image.img_to_array(img)

plt.figure(figsize=(10, 10))
# Display the image using Matplotlib
plt.imshow(img)
plt.axis('off')  # Turn off axis
plt.show()

# %% [markdown]
# Show multiple images from the dataset

# %%
#import the metadata.csv as list
import csv

def load_csv_as_list(file_path):
    data = []
    with open(file_path, 'r') as file:
        csv_reader = csv.reader(file)
        for row in csv_reader:
            data.append(row)
    return data

# Example usage:
file_path = '..//datasets//metadata.csv'
data_list = load_csv_as_list(file_path)
print(data_list)
# Out:
# [['Image Name', 'Price', 'Game Name'], ['1000410_ss_120dad19c104c03e907de65631c07e93c0a33f57.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_204e3cf48930d62c3549dbbeaa022b2a1f388d3f.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_3bde284abbdafa186b0be8b8fcaa1e3c6d76ea40.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_44469467bb90ce7d8dfa78ad235989619284e168.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_680bcbf3806f86b47029c420d4518add08f29742.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_699a255762b3b279e6a24272495fa2ede630477a.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_8374ecd0b15fbccb53db4a959a43b0b8586f346b.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_a96a106eb12e2a4ed0166697cb1b16ff32e99f77.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_b9070a83894059ddec0f2faacb1dcb6d3f9b4b30.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_dbf8f580018d66ef9a96a9cad07d
# ...

# %%
#plot a few images from the dataset
#select first 9 images of the list

image_paths = data_list[1:10]

print(image_paths)
# Out:
# [['1000410_ss_120dad19c104c03e907de65631c07e93c0a33f57.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_204e3cf48930d62c3549dbbeaa022b2a1f388d3f.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_3bde284abbdafa186b0be8b8fcaa1e3c6d76ea40.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_44469467bb90ce7d8dfa78ad235989619284e168.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_680bcbf3806f86b47029c420d4518add08f29742.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_699a255762b3b279e6a24272495fa2ede630477a.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_8374ecd0b15fbccb53db4a959a43b0b8586f346b.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_a96a106eb12e2a4ed0166697cb1b16ff32e99f77.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin'], ['1000410_ss_b9070a83894059ddec0f2faacb1dcb6d3f9b4b30.1920x1080.jpg', '3590', 'WRATH: Aeon of Ruin']]

# %%
#plot the 9 images
plt.figure(figsize=(10, 6)) #size of the window

for i, list_path in enumerate(image_paths):
    plt.subplot(3, 3, i + 1)  # Adjust subplot to 3x3 grid
    img = image.load_img("E:\\Dataset\\images\\"+list_path[0], target_size=(1080,1920))
    plt.imshow(img)
    plt.axis('off')

plt.tight_layout()  # Adjust spacing between subplots
plt.show()
